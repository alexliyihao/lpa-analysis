# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import re

# %% [markdown]
# # Data Importing

# %% [markdown]
# Grab a random one from the file list

# %%
filename = "washei50433.BQSR.recaled.bam"

# %%
def get_file(bam_name):
    '''
    given a bam name, read the variantsAnnotate.txt inside the output of Coassin pipeline
    Args:
        bam name: str, the name of the original bam file
    Return:
        pandas.DataFrame instance, the variantsAnnotate.txt file read
    '''
    return pd.read_csv(f'data/{bam_name}/variantsAnnotate/variantsAnnotate.txt', delimiter = "\t")

# %%
db = get_file(filename)
print(db.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SampleID        364 non-null    object
#  1   Pos             364 non-null    int64
#  2   Ref             364 non-null    object
#  3   Variant         364 non-null    object
#  4   Major/Minor     364 non-null    object
#  5   Variant-Level   364 non-null    float64
#  6   Coverage-FWD    364 non-null    int64
#  7   Coverage-Rev    364 non-null    int64
#  8   Coverage-Total  364 non-null    int64
#  9   TypeB           52 non-null     object
#  10  wt              364 non-null    object
#  11  mut             364 non-null    object
#  12  mylocus         364 non-null    object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 37.1+ KB
# None

# %% [markdown]
# Here checks the duplication of positions
#
# <b>Question 1: there're a amount of duplicates, how do we encode them?</b>
#
# I've checked with the original file and these duplicate do exist

# %%
db[db.Pos.duplicated(keep=False)]
# Out:
#                          SampleID   Pos Ref Variant Major/Minor  \
# 73   washei50433.BQSR.recaled.bam   943   T       G         T/G
# 74   washei50433.BQSR.recaled.bam   943   T       A         T/A
# 108  washei50433.BQSR.recaled.bam   412   C       G         C/G
# 109  washei50433.BQSR.recaled.bam   412   C       T         C/T
# 111  washei50433.BQSR.recaled.bam   410   T       A         T/A
# 112  washei50433.BQSR.recaled.bam   410   T       G         T/G
# 120  washei50433.BQSR.recaled.bam  2505   A       C         A/C
# 121  washei50433.BQSR.recaled.bam  2505   A       T         A/T
# 122  washei50433.BQSR.recaled.bam  2505   A       G         A/G
# 160  washei50433.BQSR.recaled.bam   621   T       C         T/C
# 161  washei50433.BQSR.recaled.bam   621   T       A         T/A
# 166  washei50433.BQSR.recaled.bam   612   G       T         G/T
# 167  washei50433.BQSR.recaled.bam   612   G       C         G/C
# 177  washei50433.BQSR.recaled.bam   602   G       T         G/T
# 178  washei50433.BQSR.recaled.bam   602   G       C         G/C
# 192  washei50433.BQSR.recaled.bam   675   C       T         C/T
# 193  washei50433.BQSR.recaled.bam   675   C       A         C/A
# 195  washei50433.BQSR.recaled.bam   672   A       G         A/G
# 196  washei50433.BQSR.recaled.bam   672   A       C         A/C
# 197  washei50433.BQSR.recaled.bam   666   A       T         A/T
# 198  washei50433.BQSR.recaled.bam   666   A       C         A/C
# 209  washei50433.BQSR.recaled.bam   650   A       T         A/T
# 210  washei50433.BQSR.recaled.bam   650   A       C         A/C
# 228  washei50433.BQSR.recaled.bam   588   T       A         T/A
# 229  washei50433.BQSR.recaled.bam   588   T       G         T/G
# 232  washei50433.BQSR.recaled.bam   573   C       G         C/G
# 233  washei50433.BQSR.recaled.bam   573   C       A         C/A
# 243  washei50433.BQSR.recaled.bam  4806   G       T         G/T
# 244  washei50433.BQSR.recaled.bam  4806   G       C         G/C
# 246  washei50433.BQSR.recaled.bam  4804   G       C         G/C
# 247  washei50433.BQSR.recaled.bam  4804   G       A         G/A
# 265  washei50433.BQSR.recaled.bam  4876   G       T         G/T
# 266  washei50433.BQSR.recaled.bam  4876   G       C         G/C
# 268  washei50433.BQSR.recaled.bam  4870   C       G         C/G
# 269  washei50433.BQSR.recaled.bam  4870   C       A         C/A
# 300  washei50433.BQSR.recaled.bam  4701   G       A         G/A
# 301  washei50433.BQSR.recaled.bam  4701   G       T         G/T
# 315  washei50433.BQSR.recaled.bam  4740   C       G         C/G
# 316  washei50433.BQSR.recaled.bam  4740   C       T         C/T
# 318  washei50433.BQSR.recaled.bam  4755   T       G         T/G
# 319  washei50433.BQSR.recaled.bam  4755   T       A         T/A
# 320  washei50433.BQSR.recaled.bam  4755   T       C         T/C
# 327  washei50433.BQSR.recaled.bam   766   A       C         A/C
# 328  washei50433.BQSR.recaled.bam   766   A       T         A/T
# 342  washei50433.BQSR.recaled.bam   727   T       A         T/A
# 343  washei50433.BQSR.recaled.bam   727   T       C         T/C
# 353  washei50433.BQSR.recaled.bam   707   C       A         C/A
# 354  washei50433.BQSR.recaled.bam   707   C       G         C/G
# 360  washei50433.BQSR.recaled.bam   781   G       C         G/C
# 361  washei50433.BQSR.recaled.bam   781   G       T         G/T
#
#      Variant-Level  Coverage-FWD  Coverage-Rev  Coverage-Total TypeB   wt  \
# 73          0.0607           203          1280            1483   NaN    -
# 74          0.0270           203          1280            1483   NaN    -
# 108         0.0702          1280           286            1566   yes    -
# 109         0.0307          1280           286            1566   NaN    -
# 111         0.0509          1289           282            1571   yes    -
# 112         0.0197          1289           282            1571   NaN    -
# 120         0.2213          1090          1282            2372   NaN    -
# 121         0.0160          1090          1282            2372   NaN    -
# 122         0.0076          1090          1282            2372   NaN    -
# 160         0.1805          4571          3118            7689   yes  His
# 161         0.0113          4571          3118            7689   NaN  His
# 166         0.0560          4431          2834            7265   NaN  Glu
# 167         0.0226          4431          2834            7265   NaN  Glu
# 177         0.0484          3831          2140            5971   NaN  Gly
# 178         0.0285          3831          2140            5971   NaN  Gly
# 192         0.0744          4704          4759            9463   NaN  Thr
# 193         0.0636          4704          4759            9463   NaN  Thr
# 195         0.1045          4848          4658            9506   NaN  Arg
# 196         0.0307          4848          4658            9506   NaN  Arg
# 197         0.0469          5015          4634            9649   yes  Thr
# 198         0.0216          5015          4634            9649   NaN  Thr
# 209         0.0874          5154          4151            9305   NaN  Tyr
# 210         0.0145          5154          4151            9305   NaN  Tyr
# 228         0.0386          3765          1776            5541   NaN  Thr
# 229         0.0155          3765          1776            5541   NaN  Thr
# 232         0.0245          3111          1381            4492   NaN    -
# 233         0.0223          3111          1381            4492   NaN    -
# 243         0.0479          2056          1723            3779   NaN  Arg
# 244         0.0400          2056          1723            3779   NaN  Arg
# 246         0.0282          2033          1755            3788   NaN  Thr
# 247         0.0190          2033          1755            3788   NaN  Thr
# 265         0.0479          1666          2074            3740   NaN  Ala
# 266         0.0094          1666          2074            3740   NaN  Ala
# 268         0.0591          1643          2166            3809   NaN  Ala
# 269         0.0294          1643          2166            3809   NaN  Ala
# 300         0.1301          1680           825            2505   NaN    -
# 301         0.0088          1680           825            2505   NaN    -
# 315         0.0514          2235          1402            3637   NaN    -
# 316         0.0135          2235          1402            3637   NaN    -
# 318         0.0452          2372          1630            4002   NaN  Met
# 319         0.0260          2372          1630            4002   NaN  Met
# 320         0.0147          2372          1630            4002   NaN  Met
# 327         0.0432          2410          3868            6278   NaN    -
# 328         0.0331          2410          3868            6278   NaN    -
# 342         0.1897          3522          4452            7974   NaN  Tyr
# 343         0.0227          3522          4452            7974   NaN  Tyr
# 353         0.1572          3720          4499            8219   NaN  Ser
# 354         0.0355          3720          4499            8219   NaN  Ser
# 360         0.1571          1996          3505            5501   NaN    -
# 361         0.0356          1996          3505            5501   NaN    -
#
#       mut      mylocus
# 73      -      large-I
# 74      -      large-I
# 108     -      short-I
# 109     -      short-I
# 111     -      short-I
# 112     -      short-I
# 120     -      large-I
# 121     -      large-I
# 122     -      large-I
# 160   His      Exon421
# 161   Gln      Exon421
# 166   Asp      Exon421
# 167   Asp      Exon421
# 177   Val      Exon421
# 178   Ala      Exon421
# 192   Thr      Exon421
# 193   Thr      Exon421
# 195   Arg      Exon421
# 196   Ser      Exon421
# 197   Thr      Exon421
# 198   Thr      Exon421
# 209   Phe      Exon421
# 210   Ser      Exon421
# 228   Thr      Exon421
# 229   Thr      Exon421
# 232     -  near_splice
# 233     -  near_splice
# 243   Met      Exon422
# 244   Thr      Exon422
# 246   Thr      Exon422
# 247   Thr      Exon422
# 265   Ala      Exon422
# 266   Ala      Exon422
# 268   Ala      Exon422
# 269   Ala      Exon422
# 300     -      large-I
# 301     -      large-I
# 315     -  near_splice
# 316     -  near_splice
# 318   Arg      Exon422
# 319   Lys      Exon422
# 320   Thr      Exon422
# 327     -  near_splice
# 328     -  near_splice
# 342   Asn      Exon421
# 343   His      Exon421
# 353  STOP      Exon421
# 354   Trp      Exon421
# 360     -      large-I
# 361     -      large-I

# %% [markdown]
# # Features

# %% [markdown]
# ## id

# %% [markdown]
# We no longer need the alphabetical characters -- the number digits carrys all the information we need

# %%
def extract_ID(SampleID):
    """
    Helper function clean Sample ID to pure digits
    
    Args:
        SampleID: String, in "washei*****.BQSR.recaled.bam" format, where * stand for numbers
    Return:
        String, the number characters in the middle
    """
    return re.findall(r"[0-9]+", SampleID)[0]

# %%
db.SampleID = db.SampleID.apply(extract_ID)
db.head()
# Out:
#   SampleID   Pos Ref Variant Major/Minor  Variant-Level  Coverage-FWD  \
# 0    50433   287   C       A         C/A         0.0886           450
# 1    50433   271   G       C         G/C         0.0835           425
# 2    50433  1106   G       A         G/A         0.0413            57
# 3    50433  1110   C       T         C/T         0.0640            53
# 4    50433  1124   C       G         C/G         0.0352            48
#
#    Coverage-Rev  Coverage-Total TypeB wt mut  mylocus
# 0            69             519   yes  -   -  short-I
# 1            66             491   yes  -   -  short-I
# 2           452             509   NaN  -   -  large-I
# 3           431             484   NaN  -   -  large-I
# 4           406             454   NaN  -   -  large-I

# %% [markdown]
# ## Ref, Variant, Major/Minor, and Variant-Level

# %% [markdown]
# looks like Ref/Variant = Major/Minor? Trying to find odds

# %%
db[db.Ref+"/"+db.Variant != db["Major/Minor"]]
# Out:
#     SampleID   Pos Ref Variant Major/Minor  Variant-Level  Coverage-FWD  \
# 83     50433    35   C       G         G/C         0.5874           101
# 96     50433  4358   A       G         G/A         0.4837           186
# 127    50433  4265   C       T         T/C         0.7297            92
# 165    50433  4576   C       G         G/C         0.9307           993
#
#      Coverage-Rev  Coverage-Total TypeB wt mut  mylocus
# 83             42             143   NaN  -   -  short-I
# 96             29             215    no  -   -  large-I
# 127            19             111    no  -   -  large-I
# 165           132            1125    no  -   -  large-I

# %% [markdown]
# Alright, what's the threshold?

# %%
db[db["Variant-Level"]>0.3]
# Out:
#     SampleID   Pos Ref Variant Major/Minor  Variant-Level  Coverage-FWD  \
# 83     50433    35   C       G         G/C         0.5874           101
# 96     50433  4358   A       G         G/A         0.4837           186
# 127    50433  4265   C       T         T/C         0.7297            92
# 165    50433  4576   C       G         G/C         0.9307           993
# 291    50433   859   A       G         A/G         0.3360           590
#
#      Coverage-Rev  Coverage-Total TypeB wt mut  mylocus
# 83             42             143   NaN  -   -  short-I
# 96             29             215    no  -   -  large-I
# 127            19             111    no  -   -  large-I
# 165           132            1125    no  -   -  large-I
# 291          2306            2896   NaN  -   -  large-I

# %% [markdown]
# Looks like the threshold is 0.35+?

# %% [markdown]
# ## Coverage-FWD,	Coverage-Rev, Coverage-Total

# %% [markdown]
# My guess is that Coverage-FWD + Coverage-Rev = Coverage-Total

# %%
db[db['Coverage-FWD'] + db['Coverage-Rev'] != db['Coverage-Total'] ]
# Out:
# Empty DataFrame
# Columns: [SampleID, Pos, Ref, Variant, Major/Minor, Variant-Level, Coverage-FWD, Coverage-Rev, Coverage-Total, TypeB, wt, mut, mylocus]
# Index: []

# %% [markdown]
# Thus Coverage-Total doesn't provide much info and provide colinearity in the linear regression, thus I removed them

# %%
db = db.drop(['Coverage-Total'], axis = 'columns')

# %% [markdown]
# ## TypeB

# %%
db['TypeB'].value_counts()
# Out:
# yes    49
# no      3
# Name: TypeB, dtype: int64

# %% [markdown]
# ## WT

# %%
db['wt'].value_counts()
# Out:
# -      230
# Thr     19
# Ala     18
# Arg     14
# Gly     13
# Ser     12
# Tyr     11
# Gln     10
# Val      9
# Pro      7
# Glu      6
# His      5
# Met      4
# Ile      2
# Cys      1
# Asp      1
# Asn      1
# Leu      1
# Name: wt, dtype: int64

# %%
db['mut'].value_counts()
# Out:
# -       230
# Thr      19
# Arg      14
# Ser      13
# Pro      10
# Ala       9
# Ile       8
# Gln       7
# Gly       7
# Val       7
# Asp       7
# Glu       5
# His       5
# STOP      3
# Leu       3
# Lys       3
# Phe       3
# Trp       3
# Tyr       3
# Cys       2
# Asn       2
# Met       1
# Name: mut, dtype: int64

# %% [markdown]
# ## mylocus

# %%
db['mylocus'].value_counts()
# Out:
# large-I        118
# short-I         83
# Exon421         76
# Exon422         58
# near_splice     29
# Name: mylocus, dtype: int64

# %% [markdown]
# # Summary of loading files

# %%
def data_cleaning(df):
    """
    existing data cleaning procedure
    Args:
        df: pandas.DafaFrame instance, the dataframe
    Returns:
        df: pandas.DafaFrame instance, the dataframe with cleaned ID and removed 'Coverage-Total'
    """
    df.SampleID = df.SampleID.apply(extract_ID)
    df.drop(['Coverage-Total'], axis = 'columns', inplace = True)
    return df

# %%
def data_cleaning_wrapper(path_list):
    """
    The wrapper for a loading files
    Args:
        path_list: str, the path hold all Coassin pipeline output
    Return:
        df: pandas.DafaFrame instance, all the data should be loaded
    """
    return pd.concat([
        data_cleaning(get_file(file)) 
        for file in path_list
    ], 
        axis = "index", 
        ignore_index = True)

# %%
test = ['washei49194.BQSR.recaled.bam',
 'washei62376.BQSR.recaled.bam',
 'washei45948.BQSR.recaled.bam',
 'washei55083.BQSR.recaled.bam',
 'washei50433.BQSR.recaled.bam']

# %%
df = data_cleaning_wrapper(test)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1806 entries, 0 to 1805
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SampleID       1806 non-null   object
#  1   Pos            1806 non-null   int64
#  2   Ref            1806 non-null   object
#  3   Variant        1806 non-null   object
#  4   Major/Minor    1806 non-null   object
#  5   Variant-Level  1806 non-null   float64
#  6   Coverage-FWD   1806 non-null   int64
#  7   Coverage-Rev   1806 non-null   int64
#  8   TypeB          281 non-null    object
#  9   wt             1806 non-null   object
#  10  mut            1806 non-null   object
#  11  mylocus        1806 non-null   object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 169.4+ KB

# %% [markdown]
# # Approach 1: only use the variant itself

# %% [markdown]
# Very straightforward thinking method from artificial neural network users
#
# Given a base sequence(as the reference), all of the additional traits are some function $$f(original\_q, new\_q)$$ of the original fastq file and new fastq file. If I'm finding a $$g(original\_q, new\_q, additional\_traits)$$ approximate the distribution of the phenotype, it's equivalent to
# \begin{align}
#   &g(original\_q, new\_q, additional\_traits)\\
# = &g(original\_q, new\_q, f(original_q, new_q))\\
# = &G(original\_q, new\_q)
# \end{align}
#
# Thus I only focus on the original position and the variants

# %%
def ref_variant_only(df):
    """
    a test function returning the ref_variant informations only
    """
    # change the reference-variant into one column in <reference>/<variant> format
    df["variant"] = df.Ref+"/"+df.Variant
    # only select ID, Position and Variant
    df = df[['SampleID', 'Pos', "variant"]]
    # group by SamplaID and Position
    dg = df.groupby(["SampleID","Pos"])["variant"].apply(list)
    # For each sample id column we have only one value, so expand the table with positions
    dg = pd.DataFrame(dg).stack().unstack(level=1)
    # Reset the index
    dg.reset_index(inplace = True)
    # Drop the information which is irrelavant
    dg.drop("level_1", axis = 1, inplace = True)
    dg.columns.name = None
    dg.set_index("SampleID", inplace = True)
    return dg

# %%
dg = ref_variant_only(df)

# %%
dg
# Out:
#            21     31     35     50     70     91     105    112    132   \
# SampleID
# 45948     [G/A]  [T/C]    NaN  [C/G]  [C/T]  [T/C]  [C/T]  [C/T]  [C/T]
# 49194     [G/A]  [T/C]  [C/G]  [C/G]  [C/T]  [T/C]  [C/T]  [C/T]  [C/T]
# 50433     [G/A]  [T/C]  [C/G]  [C/G]  [C/T]  [T/C]  [C/T]  [C/T]  [C/T]
# 55083     [G/A]  [T/C]    NaN  [C/G]  [C/T]  [T/C]  [C/T]  [C/T]  [C/T]
# 62376       NaN    NaN  [C/G]    NaN  [C/T]  [T/C]    NaN  [C/T]  [C/T]
#
#            141   ...   5007   5012   5035   5037   5045   5046   5052   5055  \
# SampleID         ...
# 45948     [A/G]  ...  [T/C]    NaN  [C/A]  [T/G]  [A/G]  [C/T]  [A/T]  [A/G]
# 49194     [A/G]  ...  [T/C]    NaN  [C/A]  [T/G]  [A/G]  [C/T]  [A/T]  [A/G]
# 50433     [A/G]  ...  [T/C]    NaN  [C/A]  [T/G]  [A/G]  [C/T]  [A/T]  [A/G]
# 55083     [A/G]  ...  [T/C]    NaN  [C/A]  [T/G]  [A/G]  [C/T]  [A/T]  [A/G]
# 62376     [A/G]  ...  [T/C]  [G/A]  [C/A]  [T/G]  [A/G]  [C/T]  [A/T]  [A/G]
#
#            5069   5092
# SampleID
# 45948     [C/T]  [G/T]
# 49194     [C/T]  [G/T]
# 50433     [C/T]  [G/T]
# 55083     [C/T]  [G/T]
# 62376     [C/T]  [G/T]
#
# [5 rows x 458 columns]

# %%
test = dg.iloc[2]

# %%
len(test)
# Out:
# 458

# %%
dg.index
# Out:
# Index(['45948', '49194', '50433', '55083', '62376'], dtype='object', name='SampleID')

# %%
def listize(x):
    try:
        if len(x)>1:
            return list(x)
        else:
            return x
    except:
        return x

# %%
df_old.set_index(["SampleID",'Pos'], inplace = True)
df_old
# Out:
#               variant
# SampleID Pos
# 49194    4723     G/A
#          4721     G/C
#          4727     C/T
#          4728     G/C
#          4734     G/T
# ...               ...
# 55083    4843     G/A
#          4856     G/A
#          4855     C/T
#          4862     G/T
#          4857     C/A
#
# [1442 rows x 1 columns]

# %%
df_old.unstack(level = -1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-309-396715a48b3b> in <module>
# ----> 1 df_old.unstack(level = -1)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in unstack(self, level, fill_value)
#    6384         from pandas.core.reshape.reshape import unstack
#    6385
# -> 6386         return unstack(self, level, fill_value)
#    6387
#    6388     _shared_docs[
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in unstack(obj, level, fill_value)
#     406     if isinstance(obj, DataFrame):
#     407         if isinstance(obj.index, MultiIndex):
# --> 408             return _unstack_frame(obj, level, fill_value=fill_value)
#     409         else:
#     410             return obj.T.stack(dropna=False)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in _unstack_frame(obj, level, fill_value)
#     436             value_columns=obj.columns,
#     437             fill_value=fill_value,
# --> 438             constructor=obj._constructor,
#     439         )
#     440         return unstacker.get_result()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in __init__(self, values, index, level, value_columns, fill_value, constructor)
#     139
#     140         self._make_sorted_values_labels()
# --> 141         self._make_selectors()
#     142
#     143     def _make_sorted_values_labels(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in _make_selectors(self)
#     177
#     178         if mask.sum() < len(self.index):
# --> 179             raise ValueError("Index contains duplicate entries, cannot reshape")
#     180
#     181         self.group_index = comp_index
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
# Out:
# 0     SampleID    49194
#       Pos          4723
#       variant       G/A
# 1     SampleID    49194
#       Pos          4721
#                   ...
# 1440  Pos          4862
#       variant       G/T
# 1441  SampleID    55083
#       Pos          4857
#       variant       C/A
# Length: 4326, dtype: object

# %%
count = df_old

# %%
count["variant"][count["variant"]!=1]
# Out:
# SampleID  Pos
# 45948     412     2
#           573     2
#           588     2
#           602     2
#           612     2
#                  ..
# 62376     4740    2
#           4755    3
#           4804    2
#           4806    2
#           4870    2
# Name: variant, Length: 77, dtype: int64

